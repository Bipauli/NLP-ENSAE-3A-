# %% [markdown]
# # NLP Lab: Language Models
#
# In this lab, we will build the main components of the GPT-2 model and train a small model on poems by Victor Hugo.
#
# The questions are included in this notebook. To run the training, you will need to modify the `gpt_single_head.py` file, which is also available in the Git repository.
#
# ## Data
#
# The training data consists of a collection of poems by Victor Hugo, sourced from [gutenberg.org](https://www.gutenberg.org/). The dataset is available in the `data` directory.
#
# To reduce model complexity, we will model the text at the character level. Typically, language models process sequences of subwords using [tokenizers](https://huggingface.co/docs/transformers/tokenizer_summary) such as BPE, SentencePiece, or WordPiece.
#
# #### Questions:
# - Using [collections.Counter](https://docs.python.org/3/library/collections.html#collections.Counter), display the number of unique characters in the text and the frequency of each character.

# %%
import collections

with open('data/hugo_contemplations.txt', 'r', encoding='utf-8') as f:
    text = f.read()

print(f'Number of characters in the file: {len(text)}')
##  YOUR CODE HERE
counter = collections.Counter(text)
chars = counter.keys()
vocab_size = len(chars)

print(f'Number of character in counter: {sum(counter.values())}')
print (f'{len(chars)} different characters')
print(counter)
# Out:
# Number of characters in the file: 285222
# Number of character in counter: 285222
# 101 different characters
# Counter({' ': 49127, 'e': 30253, 's': 17987, 'u': 14254, 'r': 14223, 't': 14071, 'a': 14048, 'n': 13725, 'i': 12828, 'o': 12653, 'l': 11638, '\n': 8102, 'm': 6495, 'd': 6375, ',': 6077, 'c': 5074, 'p': 4206, "'": 3820, 'v': 3492, 'é': 2943, 'b': 2783, 'f': 2772, 'h': 2221, 'q': 1956, 'g': 1790, '.': 1420, 'x': 1154, 'L': 1147, '!': 1121, 'E': 1074, ';': 1043, '-': 1020, 'j': 890, 'D': 764, 'è': 725, 'à': 706, 'y': 660, 'I': 627, 'ê': 605, 'C': 593, 'S': 545, 'A': 530, 'Q': 503, 'z': 482, 'J': 471, 'O': 450, 'T': 441, 'P': 435, '?': 388, 'V': 383, 'â': 381, 'N': 362, 'M': 344, 'ù': 298, ':': 294, 'R': 240, 'î': 214, 'U': 208, 'ô': 159, 'X': 150, '1': 146, 'H': 116, 'F': 114, '5': 111, '8': 93, 'B': 78, '«': 74, 'É': 70, '»': 69, 'G': 67, '4': 64, 'û': 62, '3': 47, 'ç': 34, 'À': 33, 'ë': 32, 'ï': 31, '2': 30, '·': 26, 'Ê': 24, '6': 23, '7': 23, 'Ô': 19, '9': 19, 'È': 11, 'k': 10, '0': 10, '_': 8, 'Z': 7, 'Æ': 4, '[': 4, ']': 4, 'w': 3, 'K': 3, 'Y': 3, 'Ë': 2, '(': 2, ')': 2, 'Â': 2, 'Î': 1, 'W': 1})

# %% [markdown]
# ### Encoding / Decoding
#
# To transform the text into a vector for the neural network, each character must be encoded as an integer.
#
# The following functions perform the encoding and decoding of characters:

# %%
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: transform a string into a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: transform a list of integers into a string


# test that your encoder/decoder is coherent
testString = "\nDemain, dès l'aube"
assert decode(encode (testString)) ==  testString

# %%
decode(encode (testString))
# Out:
# "\nDemain, dès l'aube"

# %% [markdown]
# ### Train/Validation Split
#
# Since the goal is to predict poems, the lines should not be shuffled randomly. Instead, we must preserve the order of the lines in the text and take only the first 90% for training, while using the remaining 10% to monitor learning.
#
# #### Questions:
# - Split the data into `train_data` (90%) and `val_data` (10%) using slicing on the dataset.

# %%
import torch
# Train and validation splits
data = torch.tensor(encode(text), dtype=torch.long)
## YOUR CODE HERE
# first 90% will be train, rest val
train_data= data[:int(data.shape[0] * 0.9)]
val_data = data[int(data.shape[0] * 0.9):]
###

# %% [markdown]
# ### Context
#
# The language model has a parameter that defines the maximum context size to consider when predicting the next character. This context is called `block_size`. The training data consists of sequences of consecutive characters, randomly sampled from the training set, with a length of `block_size`.
#
# If the starting character of the sequence is `i`, then the context sequence is:
# ```python
# x = data[i:i+block_size]
# ```
# And the target value to predict at each position in the context is the next character:
# ```python
# y = data[i+1:i+block_size+1]
# ```

# %%
block_size = 8

i  = torch.randint(len(data) - block_size, (1,))
print (i)
x = train_data[i:i+block_size]
y = train_data[i+1:i+1+block_size]

for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    print (f'context is >{decode(context.tolist())}< target is >{decode([target.tolist()])}<')
# Out:
# tensor([194794])
# context is >I< target is >X<
# context is >IX< target is >
# <
# context is >IX
# < target is >
# <
# context is >IX
#
# < target is >V<
# context is >IX
#
# V< target is >O<
# context is >IX
#
# VO< target is >Y<
# context is >IX
#
# VOY< target is >A<
# context is >IX
#
# VOYA< target is >G<

# %% [markdown]
# ### Defining Batches
#
# The training batches consist of multiple character sequences randomly sampled from `train_data`. To randomly select a sequence for the batch, we need to randomly pick a starting point in `train_data` and extract the following `block_size` characters. When selecting the starting point, ensure that there are enough characters remaining after it to form a full sequence of `block_size` characters.
#
# #### Questions:
# - Create the batches `x` by selecting `batch_size` sequences of length `block_size` starting from a randomly chosen index `i`. Stack the examples using `torch.stack`.
# - Create the batches `y` by adding the next character following each sequence in `x`. Stack the examples using `torch.stack`.

# %%
batch_size = 4
torch.manual_seed(2023)
# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ## YOUR CODE HERE
    # select batch_size starting points in the data, store them in a list called starting_points
    starting_points = torch.randint(len(data) - block_size, (batch_size,))
    # x is the sequence of integer starting at each straing point and of length block_size
    x = torch.stack([data[i:i+block_size] for i in starting_points])
    # y is the character after each starting position
    y = torch.stack([data[i+1:i+1+block_size] for i in starting_points])
    ### 
    # send data and target to device
    x, y = x.to(device), y.to(device)
    return x, y

# %% [markdown]
# ### First Model: A Bigram Model
#
# The first model we will implement is a bigram model. It predicts the next character based only on the current character. This model can be stored in a simple matrix: for each character (row), we store the probability distribution over all possible next characters (columns). This can be implemented using a simple [`Embedding`](https://pytorch.org/docs/stable/generated/torch.nn.Embedding.html) layer in PyTorch.
#
# #### Questions:
# - In the constructor, define an Embedding layer of size `vocab_size × vocab_size`.
# - In the `forward` method, apply the embedding layer to the batch of indices (`x`).
# - In the `forward` method, define the loss as `cross_entropy` between the predictions and the target (`y`).

# %%
import torch.nn as nn

# use a gpu if we have one
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self, vocab_size):
        super().__init__()
        # we use a simple vocab_size times vocab_size tensor to store the probabilities 
        # of each token given a single token as context in nn.Embedding
        # YOUR CODE HERE
        self.embedding = nn.Embedding(vocab_size, vocab_size)
        ## 
        
    def forward(self, idx, targets=None):

        # idx and targets are both (Batch,Time) tensor of integers
        # YOUR CODE HERE
        logits = self.embedding(idx)
        ## 
   
        # don't compute loss if we don't have targets
        if targets is None:
            loss = None
        else:
            # change the shape of the logits and target to match what is needed for CrossEntropyLoss
            # https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html
            Batch, Time, Channels = logits.shape
            logits = logits.view(Batch*Time, Channels)
            targets = targets.view(Batch*Time)
            
            # negative log likelihood between prediction and target
            # YOUR CODE HERE
            loss = nn.functional.cross_entropy(logits, targets)
            ## 

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # get the predictions
            logits, loss = self(idx)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = nn.functional.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel(vocab_size)
# send the model to device
m = model.to(device)

# %% [markdown]
# ### Model Before Training
#
# At this stage, the model has not yet been trained—it has only been initialized. However, we can already compute the loss on a random batch. Since the weights are initialized with a normal distribution \( N(0,1) \) for each dimension, the expected loss after initialization should be close to `-ln(1/vocab_size)`, as the entropy is maximal.

# %%
import math
xb, yb = get_batch('train')
logits, loss = m(xb, yb)
print (logits.shape)
print (f'Expected loss {-math.log(1.0/vocab_size)}')
print (f'Computed loss {loss}')
# Out:
# torch.Size([32, 101])
# Expected loss 4.61512051684126
# Computed loss 5.095335960388184

# %% [markdown]
# ### Using the Model for Prediction
#
# To use the model for prediction, we need to provide an initial character to start the sequence—this is called the prompt. In our case, we can initialize the generation with the newline character (`\n`) to start a new sentence.
#
# #### Questions:
# - Create a prompt as a tensor of size `(1,1)` containing the integer corresponding to the character `\n`.
# - Generate a sequence of 100 characters from this prompt using the functions `m.generate` and `decode`.
# - How does the generated sentence look?

# %%
print (encode(['\n']))
## YOUR CODE HERE
prompt = torch.LongTensor(encode(['\n'])).view(1,1)
decode(m.generate(prompt, 100)[0].tolist())
###
# Out:
# [3]
# "\n[yKtFà0«z[·9(\n,ï![ÀûQ·jkË)ùKk'-Ip0pû.[w]V0îC!ûe-Nâ-Q8hÂK: Lè?(»»TZUàyÉ,nFÎHàâçPAË8B3d-IïfP:3daèP)·4,"

# %% [markdown]
# ### Training
#
# For training, we use the [AdamW](https://pytorch.org/docs/stable/generated/torch.optim.AdamW.html) optimizer with a learning rate of `1e-3`. Each training iteration consists of the following steps:
#
# - Generate a batch
# - Apply the neural network (forward pass) and compute the loss: `model(xb, yb)`
# - Compute the gradient (after resetting accumulated gradients): `loss.backward()`
# - Update the parameters: `optimizer.step()`

# %%
max_iters = 10000
batch_size = 4
eval_interval = 10
learning_rate = 1e-3
eval_iters = 20

@torch.no_grad() # no gradient is computed here
def estimate_loss():
    """ Estimate the loss on eval_iters batch of train and val sets."""
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# re-create the model
model = BigramLanguageModel(vocab_size)
m = model.to(device)

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = m(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# step 0: train loss 5.0130, val loss 5.0282
# step 10: train loss 5.0889, val loss 5.1256
# step 20: train loss 5.0850, val loss 5.0845
# step 30: train loss 5.1031, val loss 5.0391
# step 40: train loss 5.0091, val loss 5.0483
# step 50: train loss 4.9939, val loss 5.0604
# step 60: train loss 5.0046, val loss 5.0726
# step 70: train loss 4.9728, val loss 5.0387
# step 80: train loss 5.0640, val loss 5.0929
# step 90: train loss 5.0042, val loss 4.9740
# step 100: train loss 4.9995, val loss 4.9989
# step 110: train loss 4.9889, val loss 4.9943
# step 120: train loss 4.9684, val loss 5.0431
# step 130: train loss 4.9906, val loss 4.8580
# step 140: train loss 4.8931, val loss 4.9840
# step 150: train loss 4.9607, val loss 4.9987
# step 160: train loss 4.8599, val loss 4.9637
# step 170: train loss 4.9790, val loss 4.8976
# step 180: train loss 4.9642, val loss 4.9073
# step 190: train loss 4.8731, val loss 4.9561
# step 200: train loss 4.9551, val loss 4.8439
# step 210: train loss 4.8458, val loss 4.8789
# step 220: train loss 4.9014, val loss 4.8572
# step 230: train loss 4.8944, val loss 4.9767
# step 240: train loss 4.7962, val loss 4.8379
# step 250: train loss 4.8569, val loss 4.8895
# step 260: train loss 4.8226, val loss 4.8978
# step 270: train loss 4.8631, val loss 4.8149
# step 280: train loss 4.8617, val loss 4.8188
# step 290: train loss 4.8301, val loss 4.8312
# step 300: train loss 4.8574, val loss 4.8713
# step 310: train loss 4.7542, val loss 4.8520
# step 320: train loss 4.8391, val loss 4.7955
# step 330: train loss 4.7487, val loss 4.7187
# step 340: train loss 4.8087, val loss 4.8473
# step 350: train loss 4.7943, val loss 4.8385
# step 360: train loss 4.7125, val loss 4.7950
# step 370: train loss 4.7255, val loss 4.7403
# step 380: train loss 4.7471, val loss 4.7111
# step 390: train loss 4.7335, val loss 4.8125
# step 400: train loss 4.6874, val loss 4.7191
# step 410: train loss 4.7418, val loss 4.7799
# step 420: train loss 4.7153, val loss 4.7593
# step 430: train loss 4.6683, val loss 4.6903
# step 440: train loss 4.7610, val loss 4.7529
# step 450: train loss 4.6596, val loss 4.6640
# step 460: train loss 4.7096, val loss 4.5856
# step 470: train loss 4.7239, val loss 4.6936
# step 480: train loss 4.6027, val loss 4.7206
# step 490: train loss 4.6351, val loss 4.6808
# step 500: train loss 4.6294, val loss 4.6756
# step 510: train loss 4.5559, val loss 4.6767
# step 520: train loss 4.6751, val loss 4.6506
# step 530: train loss 4.5786, val loss 4.5885
# step 540: train loss 4.5903, val loss 4.5870
# step 550: train loss 4.6109, val loss 4.7371
# step 560: train loss 4.5723, val loss 4.6219
# step 570: train loss 4.6076, val loss 4.5921
# step 580: train loss 4.5802, val loss 4.6386
# step 590: train loss 4.5816, val loss 4.5709
# step 600: train loss 4.5956, val loss 4.5866
# step 610: train loss 4.5400, val loss 4.5733
# step 620: train loss 4.5333, val loss 4.5286
# step 630: train loss 4.5500, val loss 4.5668
# step 640: train loss 4.5711, val loss 4.5066
# step 650: train loss 4.5587, val loss 4.5933
# step 660: train loss 4.5566, val loss 4.5649
# step 670: train loss 4.5602, val loss 4.4887
# step 680: train loss 4.4666, val loss 4.5483
# step 690: train loss 4.4902, val loss 4.5061
# step 700: train loss 4.5277, val loss 4.4579
# step 710: train loss 4.4729, val loss 4.5209
# step 720: train loss 4.4495, val loss 4.5033
# step 730: train loss 4.3877, val loss 4.4843
# step 740: train loss 4.4229, val loss 4.5266
# step 750: train loss 4.4141, val loss 4.4546
# step 760: train loss 4.3926, val loss 4.4559
# step 770: train loss 4.4704, val loss 4.4162
# step 780: train loss 4.3337, val loss 4.4338
# step 790: train loss 4.4834, val loss 4.3857
# step 800: train loss 4.3920, val loss 4.4166
# step 810: train loss 4.3622, val loss 4.3654
# step 820: train loss 4.4031, val loss 4.4542
# step 830: train loss 4.3453, val loss 4.4248
# step 840: train loss 4.3690, val loss 4.4714
# step 850: train loss 4.3956, val loss 4.3962
# step 860: train loss 4.3412, val loss 4.3928
# step 870: train loss 4.3070, val loss 4.3379
# step 880: train loss 4.3007, val loss 4.4373
# step 890: train loss 4.3391, val loss 4.4826
# step 900: train loss 4.3665, val loss 4.3190
# step 910: train loss 4.2833, val loss 4.3254
# step 920: train loss 4.3373, val loss 4.3738
# step 930: train loss 4.3278, val loss 4.2905
# step 940: train loss 4.3553, val loss 4.3566
# step 950: train loss 4.2779, val loss 4.3830
# step 960: train loss 4.2166, val loss 4.3528
# step 970: train loss 4.2627, val loss 4.3279
# step 980: train loss 4.2750, val loss 4.3022
# step 990: train loss 4.2783, val loss 4.3077
# step 1000: train loss 4.2133, val loss 4.3050
# step 1010: train loss 4.2236, val loss 4.2365
# step 1020: train loss 4.2765, val loss 4.2982
# step 1030: train loss 4.2172, val loss 4.3463
# step 1040: train loss 4.2223, val loss 4.2571
# step 1050: train loss 4.1869, val loss 4.3009
# step 1060: train loss 4.1867, val loss 4.2582
# step 1070: train loss 4.2116, val loss 4.2527
# step 1080: train loss 4.1722, val loss 4.2886
# step 1090: train loss 4.1980, val loss 4.1686
# step 1100: train loss 4.2253, val loss 4.1875
# step 1110: train loss 4.2097, val loss 4.2041
# step 1120: train loss 4.1785, val loss 4.2400
# step 1130: train loss 4.1436, val loss 4.1855
# step 1140: train loss 4.1424, val loss 4.2450
# step 1150: train loss 4.1696, val loss 4.1970
# step 1160: train loss 4.1286, val loss 4.2635
# step 1170: train loss 4.1205, val loss 4.1905
# step 1180: train loss 4.1319, val loss 4.1840
# step 1190: train loss 4.0852, val loss 4.1822
# step 1200: train loss 4.1013, val loss 4.1826
# step 1210: train loss 4.0915, val loss 4.1928
# step 1220: train loss 4.1627, val loss 4.1475
# step 1230: train loss 4.0616, val loss 4.1977
# step 1240: train loss 4.1207, val loss 4.1125
# step 1250: train loss 4.0796, val loss 4.1893
# step 1260: train loss 4.1397, val loss 4.2146
# step 1270: train loss 4.0728, val loss 4.1398
# step 1280: train loss 3.9980, val loss 4.1705
# step 1290: train loss 4.0831, val loss 4.1126
# step 1300: train loss 4.0791, val loss 4.1536
# step 1310: train loss 4.0233, val loss 4.0673
# step 1320: train loss 4.0862, val loss 4.1407
# step 1330: train loss 3.9995, val loss 4.1007
# step 1340: train loss 4.0093, val loss 4.1091
# step 1350: train loss 4.0301, val loss 4.1215
# step 1360: train loss 4.0197, val loss 4.0785
# step 1370: train loss 3.9863, val loss 4.1190
# step 1380: train loss 4.0035, val loss 4.0781
# step 1390: train loss 4.0278, val loss 4.0743
# step 1400: train loss 3.9958, val loss 4.0716
# step 1410: train loss 3.9241, val loss 4.0368
# step 1420: train loss 3.9727, val loss 4.0038
# step 1430: train loss 3.9347, val loss 3.9882
# step 1440: train loss 3.9533, val loss 3.8939
# step 1450: train loss 3.9890, val loss 3.9673
# step 1460: train loss 4.0082, val loss 4.0275
# step 1470: train loss 3.9434, val loss 3.9813
# step 1480: train loss 4.0054, val loss 4.0237
# step 1490: train loss 3.9642, val loss 4.0504
# step 1500: train loss 3.9239, val loss 4.0034
# step 1510: train loss 3.9393, val loss 3.8371
# step 1520: train loss 3.9587, val loss 3.9658
# step 1530: train loss 3.8931, val loss 3.9838
# step 1540: train loss 3.8942, val loss 3.9925
# step 1550: train loss 3.8234, val loss 4.0024
# step 1560: train loss 3.9290, val loss 3.9233
# step 1570: train loss 3.9670, val loss 3.9438
# step 1580: train loss 3.9026, val loss 3.9679
# step 1590: train loss 3.9100, val loss 4.0588
# step 1600: train loss 3.8699, val loss 3.9031
# step 1610: train loss 3.8218, val loss 3.9101
# step 1620: train loss 3.7861, val loss 3.9274
# step 1630: train loss 3.7920, val loss 3.9235
# step 1640: train loss 3.8243, val loss 3.8484
# step 1650: train loss 3.8812, val loss 3.9650
# step 1660: train loss 3.8779, val loss 3.9747
# step 1670: train loss 3.8503, val loss 3.9184
# step 1680: train loss 3.8164, val loss 3.8691
# step 1690: train loss 3.8339, val loss 3.8592
# step 1700: train loss 3.8790, val loss 3.8256
# step 1710: train loss 3.8094, val loss 3.8839
# step 1720: train loss 3.8050, val loss 3.8648
# step 1730: train loss 3.8144, val loss 3.7910
# step 1740: train loss 3.8131, val loss 3.8614
# step 1750: train loss 3.8503, val loss 3.8689
# step 1760: train loss 3.8193, val loss 3.8272
# step 1770: train loss 3.8356, val loss 3.8182
# step 1780: train loss 3.7702, val loss 3.8456
# step 1790: train loss 3.7905, val loss 3.8171
# step 1800: train loss 3.7478, val loss 3.8463
# step 1810: train loss 3.8070, val loss 3.8411
# step 1820: train loss 3.8148, val loss 3.8383
# step 1830: train loss 3.7973, val loss 3.7866
# step 1840: train loss 3.7609, val loss 3.7728
# step 1850: train loss 3.7700, val loss 3.7403
# step 1860: train loss 3.7846, val loss 3.7647
# step 1870: train loss 3.7452, val loss 3.8420
# step 1880: train loss 3.7765, val loss 3.7616
# step 1890: train loss 3.7823, val loss 3.7858
# step 1900: train loss 3.7434, val loss 3.7867
# step 1910: train loss 3.6867, val loss 3.8226
# step 1920: train loss 3.6631, val loss 3.7664
# step 1930: train loss 3.7337, val loss 3.7041
# step 1940: train loss 3.7748, val loss 3.7676
# step 1950: train loss 3.6900, val loss 3.7755
# step 1960: train loss 3.6687, val loss 3.7967
# step 1970: train loss 3.6764, val loss 3.8143
# step 1980: train loss 3.7023, val loss 3.6966
# step 1990: train loss 3.6529, val loss 3.7438
# step 2000: train loss 3.6230, val loss 3.7467
# step 2010: train loss 3.6567, val loss 3.6815
# step 2020: train loss 3.6378, val loss 3.7390
# step 2030: train loss 3.6277, val loss 3.6689
# step 2040: train loss 3.7074, val loss 3.8105
# step 2050: train loss 3.6490, val loss 3.7386
# step 2060: train loss 3.5787, val loss 3.6695
# step 2070: train loss 3.6562, val loss 3.7842
# step 2080: train loss 3.6691, val loss 3.7141
# step 2090: train loss 3.6497, val loss 3.6926
# step 2100: train loss 3.5708, val loss 3.7165
# step 2110: train loss 3.6563, val loss 3.5841
# step 2120: train loss 3.5999, val loss 3.7283
# step 2130: train loss 3.5966, val loss 3.5859
# step 2140: train loss 3.6464, val loss 3.6175
# step 2150: train loss 3.5530, val loss 3.5519
# step 2160: train loss 3.5788, val loss 3.7246
# step 2170: train loss 3.5360, val loss 3.6499
# step 2180: train loss 3.5912, val loss 3.7064
# step 2190: train loss 3.5167, val loss 3.5975
# step 2200: train loss 3.5429, val loss 3.5839
# step 2210: train loss 3.5042, val loss 3.6778
# step 2220: train loss 3.5973, val loss 3.7282
# step 2230: train loss 3.5328, val loss 3.6601
# step 2240: train loss 3.5800, val loss 3.6040
# step 2250: train loss 3.5384, val loss 3.6146
# step 2260: train loss 3.5864, val loss 3.5501
# step 2270: train loss 3.5843, val loss 3.5891
# step 2280: train loss 3.5626, val loss 3.5714
# step 2290: train loss 3.5196, val loss 3.6023
# step 2300: train loss 3.5324, val loss 3.6428
# step 2310: train loss 3.5936, val loss 3.6386
# step 2320: train loss 3.5334, val loss 3.6101
# step 2330: train loss 3.5404, val loss 3.5359
# step 2340: train loss 3.5195, val loss 3.5808
# step 2350: train loss 3.5043, val loss 3.5974
# step 2360: train loss 3.5255, val loss 3.5313
# step 2370: train loss 3.5057, val loss 3.6539
# step 2380: train loss 3.5135, val loss 3.5280
# step 2390: train loss 3.4797, val loss 3.5763
# step 2400: train loss 3.4592, val loss 3.5404
# step 2410: train loss 3.4774, val loss 3.5217
# step 2420: train loss 3.5642, val loss 3.5964
# step 2430: train loss 3.3609, val loss 3.5985
# step 2440: train loss 3.5047, val loss 3.6271
# step 2450: train loss 3.5200, val loss 3.5074
# step 2460: train loss 3.4301, val loss 3.6246
# step 2470: train loss 3.4358, val loss 3.6673
# step 2480: train loss 3.4385, val loss 3.5874
# step 2490: train loss 3.4772, val loss 3.4374
# step 2500: train loss 3.4494, val loss 3.5692
# step 2510: train loss 3.3991, val loss 3.5390
# step 2520: train loss 3.4140, val loss 3.5184
# step 2530: train loss 3.4376, val loss 3.4695
# step 2540: train loss 3.4702, val loss 3.5036
# step 2550: train loss 3.4013, val loss 3.5580
# step 2560: train loss 3.4818, val loss 3.5557
# step 2570: train loss 3.4223, val loss 3.4898
# step 2580: train loss 3.4764, val loss 3.4908
# step 2590: train loss 3.3805, val loss 3.5188
# step 2600: train loss 3.3479, val loss 3.5321
# step 2610: train loss 3.4155, val loss 3.5282
# step 2620: train loss 3.3721, val loss 3.4674
# step 2630: train loss 3.3808, val loss 3.4359
# step 2640: train loss 3.3424, val loss 3.4458
# step 2650: train loss 3.4320, val loss 3.3645
# step 2660: train loss 3.3232, val loss 3.4131
# step 2670: train loss 3.3699, val loss 3.4274
# step 2680: train loss 3.3817, val loss 3.4282
# step 2690: train loss 3.4048, val loss 3.4521
# step 2700: train loss 3.3083, val loss 3.4809
# step 2710: train loss 3.4016, val loss 3.4513
# step 2720: train loss 3.2538, val loss 3.3897
# step 2730: train loss 3.3424, val loss 3.4830
# step 2740: train loss 3.4027, val loss 3.4892
# step 2750: train loss 3.4047, val loss 3.4675
# step 2760: train loss 3.3606, val loss 3.4417
# step 2770: train loss 3.4249, val loss 3.4474
# step 2780: train loss 3.3377, val loss 3.4332
# step 2790: train loss 3.3948, val loss 3.3324
# step 2800: train loss 3.3229, val loss 3.4419
# step 2810: train loss 3.2894, val loss 3.3776
# step 2820: train loss 3.3630, val loss 3.3331
# step 2830: train loss 3.3628, val loss 3.3653
# step 2840: train loss 3.3129, val loss 3.5130
# step 2850: train loss 3.3584, val loss 3.4185
# step 2860: train loss 3.2222, val loss 3.3985
# step 2870: train loss 3.2476, val loss 3.3489
# step 2880: train loss 3.3422, val loss 3.3561
# step 2890: train loss 3.2942, val loss 3.3728
# step 2900: train loss 3.3076, val loss 3.3791
# step 2910: train loss 3.2635, val loss 3.3371
# step 2920: train loss 3.2512, val loss 3.4269
# step 2930: train loss 3.3012, val loss 3.3176
# step 2940: train loss 3.2374, val loss 3.3186
# step 2950: train loss 3.3130, val loss 3.3695
# step 2960: train loss 3.2999, val loss 3.2981
# step 2970: train loss 3.2613, val loss 3.3132
# step 2980: train loss 3.2990, val loss 3.4062
# step 2990: train loss 3.3011, val loss 3.3960
# step 3000: train loss 3.3062, val loss 3.3630
# step 3010: train loss 3.2415, val loss 3.2944
# step 3020: train loss 3.3005, val loss 3.2561
# step 3030: train loss 3.2539, val loss 3.4079
# step 3040: train loss 3.2282, val loss 3.3129
# step 3050: train loss 3.3395, val loss 3.3812
# step 3060: train loss 3.2254, val loss 3.3103
# step 3070: train loss 3.2901, val loss 3.3197
# step 3080: train loss 3.2171, val loss 3.3022
# step 3090: train loss 3.2497, val loss 3.4535
# step 3100: train loss 3.1864, val loss 3.3976
# step 3110: train loss 3.1990, val loss 3.3206
# step 3120: train loss 3.2293, val loss 3.3542
# step 3130: train loss 3.2370, val loss 3.2747
# step 3140: train loss 3.2703, val loss 3.2614
# step 3150: train loss 3.2005, val loss 3.2489
# step 3160: train loss 3.2104, val loss 3.3298
# step 3170: train loss 3.1496, val loss 3.1959
# step 3180: train loss 3.1776, val loss 3.2832
# step 3190: train loss 3.1964, val loss 3.3372
# step 3200: train loss 3.1731, val loss 3.3436
# step 3210: train loss 3.2986, val loss 3.2442
# step 3220: train loss 3.1698, val loss 3.2864
# step 3230: train loss 3.1773, val loss 3.2816
# step 3240: train loss 3.2856, val loss 3.3361
# step 3250: train loss 3.1754, val loss 3.2386
# step 3260: train loss 3.1588, val loss 3.3818
# step 3270: train loss 3.1479, val loss 3.2164
# step 3280: train loss 3.1814, val loss 3.2795
# step 3290: train loss 3.1928, val loss 3.2155
# step 3300: train loss 3.1681, val loss 3.1842
# step 3310: train loss 3.1475, val loss 3.1792
# step 3320: train loss 3.1411, val loss 3.3745
# step 3330: train loss 3.2360, val loss 3.2105
# step 3340: train loss 3.0974, val loss 3.2141
# step 3350: train loss 3.1612, val loss 3.2189
# step 3360: train loss 3.1703, val loss 3.1596
# step 3370: train loss 3.1177, val loss 3.3000
# step 3380: train loss 3.0927, val loss 3.2547
# step 3390: train loss 3.2050, val loss 3.2139
# step 3400: train loss 3.1400, val loss 3.2544
# step 3410: train loss 3.1842, val loss 3.2122
# step 3420: train loss 3.1084, val loss 3.1910
# step 3430: train loss 3.1486, val loss 3.1742
# step 3440: train loss 3.1704, val loss 3.2539
# step 3450: train loss 3.1339, val loss 3.2426
# step 3460: train loss 3.1405, val loss 3.2210
# step 3470: train loss 3.1149, val loss 3.2596
# step 3480: train loss 3.1182, val loss 3.2176
# step 3490: train loss 3.0775, val loss 3.1877
# step 3500: train loss 3.1129, val loss 3.2586
# step 3510: train loss 3.1535, val loss 3.2493
# step 3520: train loss 3.1584, val loss 3.1719
# step 3530: train loss 3.0649, val loss 3.2276
# step 3540: train loss 3.1348, val loss 3.3571
# step 3550: train loss 3.1424, val loss 3.2399
# step 3560: train loss 3.0411, val loss 3.1635
# step 3570: train loss 3.1056, val loss 3.1700
# step 3580: train loss 3.0479, val loss 3.1313
# step 3590: train loss 2.9784, val loss 3.1517
# step 3600: train loss 3.0891, val loss 3.0703
# step 3610: train loss 3.1236, val loss 3.1585
# step 3620: train loss 3.0919, val loss 3.1618
# step 3630: train loss 3.0284, val loss 3.1992
# step 3640: train loss 3.1973, val loss 3.1487
# step 3650: train loss 3.1073, val loss 3.1004
# step 3660: train loss 3.0560, val loss 3.1643
# step 3670: train loss 3.1163, val loss 3.0921
# step 3680: train loss 3.0685, val loss 3.2678
# step 3690: train loss 3.0330, val loss 3.2357
# step 3700: train loss 3.1280, val loss 3.1404
# step 3710: train loss 3.0964, val loss 3.1677
# step 3720: train loss 3.0668, val loss 3.1789
# step 3730: train loss 3.0634, val loss 3.2255
# step 3740: train loss 3.0392, val loss 3.0657
# step 3750: train loss 3.0099, val loss 3.1302
# step 3760: train loss 3.0733, val loss 3.0269
# step 3770: train loss 3.0935, val loss 3.1412
# step 3780: train loss 3.1197, val loss 3.1152
# step 3790: train loss 3.0743, val loss 3.0488
# step 3800: train loss 3.0719, val loss 3.1761
# step 3810: train loss 3.0690, val loss 3.1624
# step 3820: train loss 3.0367, val loss 3.0517
# step 3830: train loss 3.0350, val loss 3.2606
# step 3840: train loss 3.0978, val loss 3.1009
# step 3850: train loss 2.9876, val loss 3.1682
# step 3860: train loss 3.0033, val loss 3.1789
# step 3870: train loss 3.0787, val loss 3.1256
# step 3880: train loss 3.0156, val loss 3.1089
# step 3890: train loss 3.0721, val loss 3.1443
# step 3900: train loss 2.9883, val loss 3.0590
# step 3910: train loss 3.0216, val loss 2.9689
# step 3920: train loss 2.9912, val loss 3.0194
# step 3930: train loss 3.0935, val loss 3.0352
# step 3940: train loss 3.0525, val loss 3.1586
# step 3950: train loss 3.1149, val loss 3.0429
# step 3960: train loss 3.0158, val loss 3.1540
# step 3970: train loss 2.9819, val loss 3.1248
# step 3980: train loss 2.9792, val loss 3.1003
# step 3990: train loss 3.0512, val loss 3.1208
# step 4000: train loss 3.0182, val loss 3.1058
# step 4010: train loss 3.0373, val loss 3.0568
# step 4020: train loss 2.9256, val loss 3.1533
# step 4030: train loss 2.9066, val loss 3.1947
# step 4040: train loss 3.0168, val loss 3.1351
# step 4050: train loss 3.0096, val loss 3.1404
# step 4060: train loss 3.0055, val loss 3.1232
# step 4070: train loss 2.9083, val loss 3.0505
# step 4080: train loss 3.0433, val loss 3.1027
# step 4090: train loss 3.0165, val loss 3.0270
# step 4100: train loss 3.0315, val loss 3.1713
# step 4110: train loss 2.9808, val loss 3.1051
# step 4120: train loss 2.9535, val loss 3.1020
# step 4130: train loss 2.9797, val loss 2.9971
# step 4140: train loss 3.0302, val loss 3.0816
# step 4150: train loss 2.9935, val loss 3.0969
# step 4160: train loss 2.9612, val loss 2.9839
# step 4170: train loss 3.0350, val loss 2.9729
# step 4180: train loss 3.0045, val loss 3.0614
# step 4190: train loss 2.9228, val loss 2.9934
# step 4200: train loss 2.9516, val loss 3.0344
# step 4210: train loss 2.8589, val loss 3.0951
# step 4220: train loss 2.9928, val loss 3.0727
# step 4230: train loss 2.9561, val loss 3.0653
# step 4240: train loss 2.9872, val loss 2.9660
# step 4250: train loss 2.9526, val loss 3.0429
# step 4260: train loss 2.9450, val loss 2.9666
# step 4270: train loss 2.9220, val loss 3.0341
# step 4280: train loss 2.9295, val loss 2.9799
# step 4290: train loss 3.0005, val loss 2.9994
# step 4300: train loss 2.9498, val loss 3.0298
# step 4310: train loss 3.0322, val loss 3.0099
# step 4320: train loss 2.8872, val loss 3.0751
# step 4330: train loss 2.9087, val loss 3.0596
# step 4340: train loss 3.0264, val loss 3.0287
# step 4350: train loss 2.9133, val loss 3.0049
# step 4360: train loss 2.9335, val loss 3.0673
# step 4370: train loss 2.8790, val loss 2.9184
# step 4380: train loss 2.8686, val loss 3.0500
# step 4390: train loss 2.9563, val loss 2.9929
# step 4400: train loss 2.9491, val loss 3.0009
# step 4410: train loss 2.9885, val loss 3.0454
# step 4420: train loss 2.9346, val loss 3.0143
# step 4430: train loss 2.9115, val loss 2.9461
# step 4440: train loss 2.9142, val loss 3.0639
# step 4450: train loss 2.9108, val loss 2.9619
# step 4460: train loss 2.8967, val loss 3.0057
# step 4470: train loss 2.9332, val loss 2.9268
# step 4480: train loss 3.0003, val loss 2.9339
# step 4490: train loss 2.8897, val loss 2.9716
# step 4500: train loss 2.8963, val loss 3.0307
# step 4510: train loss 2.8436, val loss 3.0116
# step 4520: train loss 2.8676, val loss 2.9480
# step 4530: train loss 2.9013, val loss 3.0590
# step 4540: train loss 2.8528, val loss 3.0274
# step 4550: train loss 2.9547, val loss 2.9648
# step 4560: train loss 2.9000, val loss 3.1569
# step 4570: train loss 2.8459, val loss 2.9480
# step 4580: train loss 2.8871, val loss 2.8961
# step 4590: train loss 2.9032, val loss 2.8446
# step 4600: train loss 2.8970, val loss 3.0466
# step 4610: train loss 2.8679, val loss 2.9877
# step 4620: train loss 2.8191, val loss 2.9571
# step 4630: train loss 2.9136, val loss 3.0462
# step 4640: train loss 2.9182, val loss 2.9807
# step 4650: train loss 2.9244, val loss 2.9783
# step 4660: train loss 2.9291, val loss 2.9996
# step 4670: train loss 2.9146, val loss 2.9518
# step 4680: train loss 2.9153, val loss 2.9101
# step 4690: train loss 2.8404, val loss 2.9696
# step 4700: train loss 2.8857, val loss 2.9112
# step 4710: train loss 2.9251, val loss 2.9470
# step 4720: train loss 2.8848, val loss 3.0077
# step 4730: train loss 2.8407, val loss 2.9798
# step 4740: train loss 2.8281, val loss 2.9693
# step 4750: train loss 2.9168, val loss 3.0258
# step 4760: train loss 2.8611, val loss 2.9368
# step 4770: train loss 2.9115, val loss 2.9273
# step 4780: train loss 2.8270, val loss 2.9987
# step 4790: train loss 2.8443, val loss 2.9457
# step 4800: train loss 2.8429, val loss 2.9600
# step 4810: train loss 2.8607, val loss 2.9502
# step 4820: train loss 2.8701, val loss 2.8675
# step 4830: train loss 2.9170, val loss 2.9198
# step 4840: train loss 2.8807, val loss 2.9382
# step 4850: train loss 2.8309, val loss 3.0252
# step 4860: train loss 2.8331, val loss 2.8993
# step 4870: train loss 2.8036, val loss 2.8673
# step 4880: train loss 2.7802, val loss 2.9210
# step 4890: train loss 2.8300, val loss 2.8902
# step 4900: train loss 2.9019, val loss 2.9447
# step 4910: train loss 2.8087, val loss 2.8619
# step 4920: train loss 2.8739, val loss 2.8733
# step 4930: train loss 2.9179, val loss 2.8524
# step 4940: train loss 2.7766, val loss 2.8776
# step 4950: train loss 2.8454, val loss 2.9333
# step 4960: train loss 2.8223, val loss 2.9377
# step 4970: train loss 2.8948, val loss 2.8540
# step 4980: train loss 2.9057, val loss 2.8941
# step 4990: train loss 2.8813, val loss 2.8723
# step 5000: train loss 2.7446, val loss 2.8316
# step 5010: train loss 2.8642, val loss 2.9542
# step 5020: train loss 2.8323, val loss 2.8692
# step 5030: train loss 2.8255, val loss 2.9309
# step 5040: train loss 2.8274, val loss 2.9134
# step 5050: train loss 2.8334, val loss 2.9971
# step 5060: train loss 2.8813, val loss 2.9286
# step 5070: train loss 2.8031, val loss 2.8676
# step 5080: train loss 2.9247, val loss 2.7392
# step 5090: train loss 2.7933, val loss 2.9317
# step 5100: train loss 2.7870, val loss 2.9191
# step 5110: train loss 2.9531, val loss 2.7804
# step 5120: train loss 2.8379, val loss 2.9277
# step 5130: train loss 2.7931, val loss 2.9725
# step 5140: train loss 2.7859, val loss 2.8562
# step 5150: train loss 2.8495, val loss 3.0412
# step 5160: train loss 2.7798, val loss 2.8366
# step 5170: train loss 2.8228, val loss 2.8584
# step 5180: train loss 2.8264, val loss 3.0026
# step 5190: train loss 2.7670, val loss 2.8137
# step 5200: train loss 2.7718, val loss 2.7471
# step 5210: train loss 2.7627, val loss 2.8418
# step 5220: train loss 2.8408, val loss 2.8078
# step 5230: train loss 2.8243, val loss 2.7246
# step 5240: train loss 2.7686, val loss 2.8847
# step 5250: train loss 2.8031, val loss 2.8632
# step 5260: train loss 2.7481, val loss 2.7850
# step 5270: train loss 2.8009, val loss 2.8381
# step 5280: train loss 2.8607, val loss 2.8713
# step 5290: train loss 2.8462, val loss 2.8806
# step 5300: train loss 2.7125, val loss 2.8258
# step 5310: train loss 2.7658, val loss 2.9258
# step 5320: train loss 2.7552, val loss 2.9760
# step 5330: train loss 2.7555, val loss 2.9013
# step 5340: train loss 2.7677, val loss 2.7797
# step 5350: train loss 2.7819, val loss 2.9363
# step 5360: train loss 2.7807, val loss 2.8420
# step 5370: train loss 2.7716, val loss 2.9057
# step 5380: train loss 2.7648, val loss 2.9126
# step 5390: train loss 2.7657, val loss 2.7218
# step 5400: train loss 2.8771, val loss 2.7943
# step 5410: train loss 2.8438, val loss 2.9680
# step 5420: train loss 2.7206, val loss 2.8978
# step 5430: train loss 2.7752, val loss 2.8125
# step 5440: train loss 2.8430, val loss 2.8249
# step 5450: train loss 2.7893, val loss 2.8861
# step 5460: train loss 2.7127, val loss 2.8179
# step 5470: train loss 2.8007, val loss 2.8324
# step 5480: train loss 2.8147, val loss 2.8684
# step 5490: train loss 2.7479, val loss 2.7810
# step 5500: train loss 2.7366, val loss 2.8737
# step 5510: train loss 2.8354, val loss 2.7316
# step 5520: train loss 2.7342, val loss 2.8078
# step 5530: train loss 2.7427, val loss 2.8997
# step 5540: train loss 2.7640, val loss 2.7723
# step 5550: train loss 2.8001, val loss 2.8532
# step 5560: train loss 2.7590, val loss 2.7360
# step 5570: train loss 2.7571, val loss 2.8542
# step 5580: train loss 2.7692, val loss 2.8944
# step 5590: train loss 2.8015, val loss 2.8721
# step 5600: train loss 2.8168, val loss 2.8508
# step 5610: train loss 2.8622, val loss 2.7990
# step 5620: train loss 2.7726, val loss 2.8647
# step 5630: train loss 2.6742, val loss 2.8103
# step 5640: train loss 2.7309, val loss 2.8567
# step 5650: train loss 2.7505, val loss 2.7775
# step 5660: train loss 2.7109, val loss 2.8948
# step 5670: train loss 2.8237, val loss 2.8150
# step 5680: train loss 2.7093, val loss 2.7798
# step 5690: train loss 2.7301, val loss 2.8573
# step 5700: train loss 2.8427, val loss 2.8436
# step 5710: train loss 2.7610, val loss 2.7872
# step 5720: train loss 2.7655, val loss 2.8622
# step 5730: train loss 2.6886, val loss 2.8967
# step 5740: train loss 2.7674, val loss 2.7601
# step 5750: train loss 2.7011, val loss 2.8646
# step 5760: train loss 2.7597, val loss 2.8501
# step 5770: train loss 2.8255, val loss 2.8739
# step 5780: train loss 2.7971, val loss 2.8690
# step 5790: train loss 2.7401, val loss 2.8328
# step 5800: train loss 2.6082, val loss 2.8482
# step 5810: train loss 2.7113, val loss 2.8835
# step 5820: train loss 2.7932, val loss 2.8079
# step 5830: train loss 2.7343, val loss 2.7844
# step 5840: train loss 2.7127, val loss 2.8284
# step 5850: train loss 2.7309, val loss 2.9010
# step 5860: train loss 2.8409, val loss 2.7906
# step 5870: train loss 2.7118, val loss 2.8373
# step 5880: train loss 2.8057, val loss 2.7728
# step 5890: train loss 2.6882, val loss 2.6989
# step 5900: train loss 2.7352, val loss 2.8938
# step 5910: train loss 2.6581, val loss 2.8227
# step 5920: train loss 2.7081, val loss 2.9059
# step 5930: train loss 2.6537, val loss 2.7388
# step 5940: train loss 2.7048, val loss 2.8547
# step 5950: train loss 2.6546, val loss 2.7970
# step 5960: train loss 2.7018, val loss 2.7294
# step 5970: train loss 2.6741, val loss 2.7529
# step 5980: train loss 2.7210, val loss 2.8151
# step 5990: train loss 2.7170, val loss 3.0006
# step 6000: train loss 2.7240, val loss 2.7316
# step 6010: train loss 2.6697, val loss 2.7834
# step 6020: train loss 2.7053, val loss 2.7417
# step 6030: train loss 2.7057, val loss 2.8951
# step 6040: train loss 2.7804, val loss 2.7358
# step 6050: train loss 2.7448, val loss 2.8344
# step 6060: train loss 2.7012, val loss 2.7146
# step 6070: train loss 2.6926, val loss 2.8172
# step 6080: train loss 2.7194, val loss 2.7634
# step 6090: train loss 2.6830, val loss 2.7908
# step 6100: train loss 2.7617, val loss 2.8424
# step 6110: train loss 2.6984, val loss 2.6495
# step 6120: train loss 2.7174, val loss 2.7745
# step 6130: train loss 2.7411, val loss 2.9284
# step 6140: train loss 2.6608, val loss 2.7681
# step 6150: train loss 2.7115, val loss 2.7206
# step 6160: train loss 2.7981, val loss 2.7325
# step 6170: train loss 2.6785, val loss 2.7734
# step 6180: train loss 2.6795, val loss 2.8854
# step 6190: train loss 2.6542, val loss 2.7555
# step 6200: train loss 2.6755, val loss 2.7739
# step 6210: train loss 2.6638, val loss 2.7721
# step 6220: train loss 2.6735, val loss 2.8095
# step 6230: train loss 2.6186, val loss 2.8145
# step 6240: train loss 2.6638, val loss 2.8494
# step 6250: train loss 2.6560, val loss 2.8036
# step 6260: train loss 2.7441, val loss 2.7932
# step 6270: train loss 2.7128, val loss 2.7904
# step 6280: train loss 2.8160, val loss 2.7388
# step 6290: train loss 2.6779, val loss 2.7309
# step 6300: train loss 2.6326, val loss 2.6056
# step 6310: train loss 2.6664, val loss 2.7527
# step 6320: train loss 2.6783, val loss 2.8083
# step 6330: train loss 2.7316, val loss 2.7726
# step 6340: train loss 2.7738, val loss 2.6899
# step 6350: train loss 2.7088, val loss 2.8833
# step 6360: train loss 2.6229, val loss 2.7244
# step 6370: train loss 2.6508, val loss 2.8137
# step 6380: train loss 2.6322, val loss 2.7948
# step 6390: train loss 2.7071, val loss 2.8264
# step 6400: train loss 2.6189, val loss 2.8004
# step 6410: train loss 2.7036, val loss 2.7922
# step 6420: train loss 2.6588, val loss 2.6980
# step 6430: train loss 2.7352, val loss 2.7917
# step 6440: train loss 2.6676, val loss 2.8135
# step 6450: train loss 2.7000, val loss 2.8646
# step 6460: train loss 2.6514, val loss 2.6802
# step 6470: train loss 2.7542, val loss 2.6800
# step 6480: train loss 2.7147, val loss 2.7377
# step 6490: train loss 2.7287, val loss 2.8310
# step 6500: train loss 2.5847, val loss 2.8302
# step 6510: train loss 2.6302, val loss 2.7418
# step 6520: train loss 2.6406, val loss 2.7846
# step 6530: train loss 2.6383, val loss 2.7822
# step 6540: train loss 2.7047, val loss 2.8811
# step 6550: train loss 2.6756, val loss 2.6515
# step 6560: train loss 2.6721, val loss 2.8373
# step 6570: train loss 2.6332, val loss 2.7912
# step 6580: train loss 2.6135, val loss 2.7416
# step 6590: train loss 2.6554, val loss 2.7489
# step 6600: train loss 2.6937, val loss 2.6910
# step 6610: train loss 2.6918, val loss 2.7397
# step 6620: train loss 2.6387, val loss 2.6799
# step 6630: train loss 2.7115, val loss 2.7550
# step 6640: train loss 2.6731, val loss 2.7701
# step 6650: train loss 2.5840, val loss 2.7169
# step 6660: train loss 2.5677, val loss 2.7652
# step 6670: train loss 2.6512, val loss 2.7146
# step 6680: train loss 2.5866, val loss 2.7291
# step 6690: train loss 2.6624, val loss 2.6862
# step 6700: train loss 2.6965, val loss 2.7040
# step 6710: train loss 2.6448, val loss 2.7584
# step 6720: train loss 2.6516, val loss 2.7562
# step 6730: train loss 2.7448, val loss 2.7630
# step 6740: train loss 2.6987, val loss 2.6852
# step 6750: train loss 2.6295, val loss 2.7426
# step 6760: train loss 2.6322, val loss 2.7338
# step 6770: train loss 2.6680, val loss 2.6868
# step 6780: train loss 2.6615, val loss 2.7783
# step 6790: train loss 2.6585, val loss 2.6883
# step 6800: train loss 2.6464, val loss 2.7948
# step 6810: train loss 2.6214, val loss 2.7726
# step 6820: train loss 2.6165, val loss 2.7741
# step 6830: train loss 2.6571, val loss 2.7703
# step 6840: train loss 2.6170, val loss 2.8006
# step 6850: train loss 2.6007, val loss 2.6524
# step 6860: train loss 2.6775, val loss 2.7699
# step 6870: train loss 2.6403, val loss 2.7314
# step 6880: train loss 2.6291, val loss 2.6808
# step 6890: train loss 2.6995, val loss 2.7843
# step 6900: train loss 2.7096, val loss 2.8033
# step 6910: train loss 2.6932, val loss 2.7699
# step 6920: train loss 2.6662, val loss 2.7294
# step 6930: train loss 2.6171, val loss 2.7944
# step 6940: train loss 2.7081, val loss 2.6830
# step 6950: train loss 2.6261, val loss 2.7185
# step 6960: train loss 2.5747, val loss 2.6959
# step 6970: train loss 2.6153, val loss 2.6900
# step 6980: train loss 2.5936, val loss 2.7891
# step 6990: train loss 2.6181, val loss 2.6586
# step 7000: train loss 2.6301, val loss 2.7648
# step 7010: train loss 2.6536, val loss 2.7569
# step 7020: train loss 2.6118, val loss 2.7518
# step 7030: train loss 2.5784, val loss 2.7608
# step 7040: train loss 2.6063, val loss 2.6075
# step 7050: train loss 2.6180, val loss 2.6623
# step 7060: train loss 2.7653, val loss 2.7437
# step 7070: train loss 2.6311, val loss 2.7582
# step 7080: train loss 2.6115, val loss 2.7533
# step 7090: train loss 2.6057, val loss 2.7736
# step 7100: train loss 2.5810, val loss 2.5981
# step 7110: train loss 2.7147, val loss 2.7507
# step 7120: train loss 2.6238, val loss 2.7284
# step 7130: train loss 2.6055, val loss 2.7164
# step 7140: train loss 2.6413, val loss 2.6139
# step 7150: train loss 2.6742, val loss 2.6481
# step 7160: train loss 2.6260, val loss 2.7173
# step 7170: train loss 2.6395, val loss 2.6789
# step 7180: train loss 2.6466, val loss 2.7572
# step 7190: train loss 2.6768, val loss 2.7276
# step 7200: train loss 2.6425, val loss 2.7031
# step 7210: train loss 2.5880, val loss 2.9350
# step 7220: train loss 2.6641, val loss 2.6748
# step 7230: train loss 2.6546, val loss 2.7233
# step 7240: train loss 2.6977, val loss 2.7518
# step 7250: train loss 2.5927, val loss 2.6091
# step 7260: train loss 2.6940, val loss 2.6905
# step 7270: train loss 2.6483, val loss 2.7205
# step 7280: train loss 2.5745, val loss 2.7593
# step 7290: train loss 2.6010, val loss 2.6360
# step 7300: train loss 2.5781, val loss 2.7347
# step 7310: train loss 2.6089, val loss 2.7282
# step 7320: train loss 2.6026, val loss 2.6256
# step 7330: train loss 2.5871, val loss 2.6896
# step 7340: train loss 2.6193, val loss 2.7266
# step 7350: train loss 2.6210, val loss 2.6636
# step 7360: train loss 2.6528, val loss 2.6576
# step 7370: train loss 2.5610, val loss 2.7185
# step 7380: train loss 2.5677, val loss 2.7190
# step 7390: train loss 2.6904, val loss 2.7368
# step 7400: train loss 2.5873, val loss 2.6585
# step 7410: train loss 2.5683, val loss 2.7472
# step 7420: train loss 2.5414, val loss 2.7410
# step 7430: train loss 2.5939, val loss 2.7214
# step 7440: train loss 2.5745, val loss 2.6651
# step 7450: train loss 2.6395, val loss 2.6769
# step 7460: train loss 2.5828, val loss 2.6901
# step 7470: train loss 2.5913, val loss 2.6853
# step 7480: train loss 2.5906, val loss 2.6701
# step 7490: train loss 2.6732, val loss 2.7180
# step 7500: train loss 2.6087, val loss 2.5738
# step 7510: train loss 2.6246, val loss 2.7284
# step 7520: train loss 2.6664, val loss 2.6438
# step 7530: train loss 2.5432, val loss 2.7000
# step 7540: train loss 2.5788, val loss 2.6572
# step 7550: train loss 2.6250, val loss 2.6147
# step 7560: train loss 2.6449, val loss 2.7064
# step 7570: train loss 2.5497, val loss 2.6266
# step 7580: train loss 2.5902, val loss 2.6063
# step 7590: train loss 2.5504, val loss 2.7433
# step 7600: train loss 2.5886, val loss 2.7024
# step 7610: train loss 2.5930, val loss 2.6420
# step 7620: train loss 2.5347, val loss 2.7024
# step 7630: train loss 2.5457, val loss 2.6818
# step 7640: train loss 2.6305, val loss 2.6785
# step 7650: train loss 2.5690, val loss 2.5737
# step 7660: train loss 2.5468, val loss 2.5944
# step 7670: train loss 2.5898, val loss 2.7256
# step 7680: train loss 2.5530, val loss 2.6073
# step 7690: train loss 2.5818, val loss 2.6502
# step 7700: train loss 2.5494, val loss 2.5864
# step 7710: train loss 2.7103, val loss 2.7146
# step 7720: train loss 2.5860, val loss 2.6622
# step 7730: train loss 2.6593, val loss 2.7340
# step 7740: train loss 2.5626, val loss 2.6111
# step 7750: train loss 2.6437, val loss 2.6647
# step 7760: train loss 2.5836, val loss 2.6530
# step 7770: train loss 2.5509, val loss 2.6714
# step 7780: train loss 2.5462, val loss 2.7312
# step 7790: train loss 2.6173, val loss 2.6375
# step 7800: train loss 2.5536, val loss 2.6719
# step 7810: train loss 2.7568, val loss 2.7571
# step 7820: train loss 2.5828, val loss 2.6923
# step 7830: train loss 2.5763, val loss 2.6923
# step 7840: train loss 2.5660, val loss 2.7191
# step 7850: train loss 2.6084, val loss 2.6069
# step 7860: train loss 2.5556, val loss 2.7547
# step 7870: train loss 2.5693, val loss 2.7131
# step 7880: train loss 2.5806, val loss 2.5854
# step 7890: train loss 2.5515, val loss 2.7032
# step 7900: train loss 2.5516, val loss 2.7805
# step 7910: train loss 2.6182, val loss 2.5808
# step 7920: train loss 2.5115, val loss 2.8109
# step 7930: train loss 2.5645, val loss 2.7152
# step 7940: train loss 2.6309, val loss 2.6064
# step 7950: train loss 2.5852, val loss 2.6024
# step 7960: train loss 2.5938, val loss 2.6565
# step 7970: train loss 2.5637, val loss 2.6405
# step 7980: train loss 2.5625, val loss 2.7266
# step 7990: train loss 2.5639, val loss 2.6230
# step 8000: train loss 2.5986, val loss 2.8270
# step 8010: train loss 2.5388, val loss 2.6818
# step 8020: train loss 2.4762, val loss 2.6412
# step 8030: train loss 2.5331, val loss 2.6629
# step 8040: train loss 2.5188, val loss 2.7533
# step 8050: train loss 2.5586, val loss 2.7148
# step 8060: train loss 2.5893, val loss 2.6237
# step 8070: train loss 2.4967, val loss 2.6561
# step 8080: train loss 2.6105, val loss 2.5836
# step 8090: train loss 2.5592, val loss 2.6248
# step 8100: train loss 2.6884, val loss 2.6766
# step 8110: train loss 2.5913, val loss 2.6942
# step 8120: train loss 2.5342, val loss 2.6425
# step 8130: train loss 2.6092, val loss 2.5835
# step 8140: train loss 2.6011, val loss 2.6245
# step 8150: train loss 2.5776, val loss 2.6620
# step 8160: train loss 2.5663, val loss 2.7343
# step 8170: train loss 2.5546, val loss 2.7303
# step 8180: train loss 2.6441, val loss 2.6932
# step 8190: train loss 2.5322, val loss 2.6429
# step 8200: train loss 2.5243, val loss 2.5639
# step 8210: train loss 2.5034, val loss 2.6818
# step 8220: train loss 2.5855, val loss 2.6425
# step 8230: train loss 2.5432, val loss 2.6434
# step 8240: train loss 2.5970, val loss 2.7402
# step 8250: train loss 2.5985, val loss 2.5593
# step 8260: train loss 2.5273, val loss 2.6047
# step 8270: train loss 2.5530, val loss 2.6111
# step 8280: train loss 2.5775, val loss 2.6536
# step 8290: train loss 2.5902, val loss 2.7245
# step 8300: train loss 2.5326, val loss 2.6982
# step 8310: train loss 2.5691, val loss 2.5004
# step 8320: train loss 2.4694, val loss 2.5956
# step 8330: train loss 2.5086, val loss 2.6346
# step 8340: train loss 2.5776, val loss 2.5792
# step 8350: train loss 2.5654, val loss 2.6789
# step 8360: train loss 2.6441, val loss 2.7556
# step 8370: train loss 2.5278, val loss 2.6796
# step 8380: train loss 2.6105, val loss 2.6167
# step 8390: train loss 2.5395, val loss 2.6374
# step 8400: train loss 2.6207, val loss 2.6356
# step 8410: train loss 2.5302, val loss 2.6576
# step 8420: train loss 2.4981, val loss 2.6586
# step 8430: train loss 2.5789, val loss 2.5754
# step 8440: train loss 2.5542, val loss 2.6312
# step 8450: train loss 2.5482, val loss 2.6126
# step 8460: train loss 2.6648, val loss 2.5992
# step 8470: train loss 2.5180, val loss 2.6820
# step 8480: train loss 2.4943, val loss 2.6429
# step 8490: train loss 2.5722, val loss 2.6109
# step 8500: train loss 2.5700, val loss 2.6162
# step 8510: train loss 2.5675, val loss 2.6350
# step 8520: train loss 2.5292, val loss 2.6069
# step 8530: train loss 2.5406, val loss 2.6334
# step 8540: train loss 2.4917, val loss 2.5947
# step 8550: train loss 2.6678, val loss 2.5657
# step 8560: train loss 2.6097, val loss 2.5836
# step 8570: train loss 2.5957, val loss 2.6304
# step 8580: train loss 2.5503, val loss 2.6171
# step 8590: train loss 2.4721, val loss 2.4778
# step 8600: train loss 2.5277, val loss 2.6140
# step 8610: train loss 2.5277, val loss 2.6137
# step 8620: train loss 2.5347, val loss 2.7187
# step 8630: train loss 2.5789, val loss 2.7125
# step 8640: train loss 2.5617, val loss 2.6203
# step 8650: train loss 2.6058, val loss 2.6559
# step 8660: train loss 2.5872, val loss 2.5802
# step 8670: train loss 2.5076, val loss 2.6368
# step 8680: train loss 2.5827, val loss 2.6972
# step 8690: train loss 2.5495, val loss 2.5562
# step 8700: train loss 2.5603, val loss 2.6790
# step 8710: train loss 2.5266, val loss 2.6117
# step 8720: train loss 2.5512, val loss 2.6338
# step 8730: train loss 2.4781, val loss 2.6233
# step 8740: train loss 2.5670, val loss 2.6980
# step 8750: train loss 2.6968, val loss 2.6695
# step 8760: train loss 2.5534, val loss 2.6224
# step 8770: train loss 2.5296, val loss 2.7244
# step 8780: train loss 2.5175, val loss 2.5966
# step 8790: train loss 2.5193, val loss 2.5924
# step 8800: train loss 2.5402, val loss 2.6447
# step 8810: train loss 2.5331, val loss 2.6123
# step 8820: train loss 2.4887, val loss 2.6199
# step 8830: train loss 2.5207, val loss 2.5976
# step 8840: train loss 2.5891, val loss 2.5620
# step 8850: train loss 2.4928, val loss 2.5769
# step 8860: train loss 2.5520, val loss 2.5857
# step 8870: train loss 2.5210, val loss 2.5324
# step 8880: train loss 2.4957, val loss 2.6651
# step 8890: train loss 2.5249, val loss 2.5833
# step 8900: train loss 2.5888, val loss 2.5564
# step 8910: train loss 2.5576, val loss 2.7039
# step 8920: train loss 2.5339, val loss 2.5356
# step 8930: train loss 2.5076, val loss 2.6145
# step 8940: train loss 2.5387, val loss 2.6709
# step 8950: train loss 2.5019, val loss 2.6821
# step 8960: train loss 2.5045, val loss 2.6003
# step 8970: train loss 2.5495, val loss 2.5372
# step 8980: train loss 2.5094, val loss 2.6024
# step 8990: train loss 2.5673, val loss 2.6396
# step 9000: train loss 2.5789, val loss 2.6036
# step 9010: train loss 2.6000, val loss 2.7329
# step 9020: train loss 2.5886, val loss 2.5844
# step 9030: train loss 2.4774, val loss 2.6082
# step 9040: train loss 2.4643, val loss 2.6625
# step 9050: train loss 2.5199, val loss 2.6410
# step 9060: train loss 2.5335, val loss 2.5540
# step 9070: train loss 2.5003, val loss 2.6138
# step 9080: train loss 2.4869, val loss 2.6698
# step 9090: train loss 2.6299, val loss 2.6392
# step 9100: train loss 2.5865, val loss 2.7571
# step 9110: train loss 2.5717, val loss 2.5794
# step 9120: train loss 2.5271, val loss 2.6159
# step 9130: train loss 2.5050, val loss 2.5375
# step 9140: train loss 2.4351, val loss 2.5648
# step 9150: train loss 2.5867, val loss 2.5820
# step 9160: train loss 2.5388, val loss 2.6017
# step 9170: train loss 2.5239, val loss 2.6049
# step 9180: train loss 2.5086, val loss 2.6046
# step 9190: train loss 2.5255, val loss 2.6701
# step 9200: train loss 2.5165, val loss 2.4822
# step 9210: train loss 2.4384, val loss 2.7301
# step 9220: train loss 2.5411, val loss 2.6052
# step 9230: train loss 2.5512, val loss 2.4747
# step 9240: train loss 2.5310, val loss 2.6584
# step 9250: train loss 2.5043, val loss 2.6232
# step 9260: train loss 2.5732, val loss 2.5518
# step 9270: train loss 2.4777, val loss 2.4954
# step 9280: train loss 2.5284, val loss 2.6129
# step 9290: train loss 2.5637, val loss 2.5909
# step 9300: train loss 2.5174, val loss 2.5566
# step 9310: train loss 2.5252, val loss 2.4839
# step 9320: train loss 2.5852, val loss 2.7503
# step 9330: train loss 2.5104, val loss 2.5682
# step 9340: train loss 2.4748, val loss 2.5388
# step 9350: train loss 2.4634, val loss 2.6347
# step 9360: train loss 2.4506, val loss 2.6215
# step 9370: train loss 2.5001, val loss 2.6556
# step 9380: train loss 2.5628, val loss 2.6656
# step 9390: train loss 2.4856, val loss 2.5249
# step 9400: train loss 2.4353, val loss 2.5253
# step 9410: train loss 2.4806, val loss 2.6353
# step 9420: train loss 2.5181, val loss 2.6031
# step 9430: train loss 2.5520, val loss 2.6023
# step 9440: train loss 2.5184, val loss 2.5609
# step 9450: train loss 2.4826, val loss 2.5793
# step 9460: train loss 2.5633, val loss 2.5968
# step 9470: train loss 2.5102, val loss 2.5971
# step 9480: train loss 2.4907, val loss 2.5864
# step 9490: train loss 2.6089, val loss 2.5503
# step 9500: train loss 2.5808, val loss 2.5915
# step 9510: train loss 2.5412, val loss 2.6071
# step 9520: train loss 2.4044, val loss 2.5999
# step 9530: train loss 2.5036, val loss 2.5671
# step 9540: train loss 2.5314, val loss 2.4822
# step 9550: train loss 2.5244, val loss 2.6148
# step 9560: train loss 2.4582, val loss 2.5424
# step 9570: train loss 2.4871, val loss 2.7299
# step 9580: train loss 2.5399, val loss 2.5589
# step 9590: train loss 2.4363, val loss 2.5034
# step 9600: train loss 2.5440, val loss 2.5068
# step 9610: train loss 2.4656, val loss 2.5047
# step 9620: train loss 2.4156, val loss 2.5949
# step 9630: train loss 2.5631, val loss 2.6107
# step 9640: train loss 2.4755, val loss 2.5458
# step 9650: train loss 2.4593, val loss 2.5362
# step 9660: train loss 2.6200, val loss 2.5326
# step 9670: train loss 2.5364, val loss 2.5472
# step 9680: train loss 2.5021, val loss 2.5882
# step 9690: train loss 2.5643, val loss 2.5538
# step 9700: train loss 2.5304, val loss 2.5499
# step 9710: train loss 2.4771, val loss 2.5128
# step 9720: train loss 2.5141, val loss 2.5796
# step 9730: train loss 2.4805, val loss 2.6770
# step 9740: train loss 2.5227, val loss 2.5421
# step 9750: train loss 2.5082, val loss 2.7302
# step 9760: train loss 2.5475, val loss 2.5388
# step 9770: train loss 2.5192, val loss 2.5465
# step 9780: train loss 2.4799, val loss 2.5157
# step 9790: train loss 2.4941, val loss 2.5723
# step 9800: train loss 2.3831, val loss 2.4932
# step 9810: train loss 2.5107, val loss 2.5314
# step 9820: train loss 2.5503, val loss 2.5341
# step 9830: train loss 2.4857, val loss 2.4672
# step 9840: train loss 2.5400, val loss 2.5401
# step 9850: train loss 2.5241, val loss 2.5100
# step 9860: train loss 2.4594, val loss 2.4887
# step 9870: train loss 2.5676, val loss 2.5311
# step 9880: train loss 2.4167, val loss 2.4987
# step 9890: train loss 2.5728, val loss 2.5548
# step 9900: train loss 2.5369, val loss 2.6184
# step 9910: train loss 2.4825, val loss 2.5496
# step 9920: train loss 2.5392, val loss 2.4741
# step 9930: train loss 2.5207, val loss 2.6081
# step 9940: train loss 2.4514, val loss 2.4958
# step 9950: train loss 2.5358, val loss 2.5785
# step 9960: train loss 2.4352, val loss 2.4695
# step 9970: train loss 2.4984, val loss 2.5177
# step 9980: train loss 2.4551, val loss 2.5352
# step 9990: train loss 2.5032, val loss 2.6798

# %% [markdown]
# Once the network has been trained for 100 iterations, we can generate a sequence of characters.
#
# #### Questions:
# - What is the effect of training?
# - Increase the number of iterations to 1,000 and then to 10,000. Note the obtained loss and the generated sentence. What do you observe?

# %%
idx = torch.ones((1,1), dtype=torch.long)*3
print (decode(m.generate(idx, max_new_tokens=100)[0].tolist()))
# Out:
# Xébrentiteuivoi?9èç[ngoncouchaut,uran les, oul vareroibef, digerphé ffle.squt,
# RRu vu? êous,  vierém

# %% [markdown]
# - 1000 iterations : ygùbAçWL'à!çgfréyWH3kUÊ_W]!)rvçGtgo67JOhH7îz0ÔdSFp(Àï[ÈïF'êqÎGt! mÔÆXCËàmËÂPZu8wÀ8ôeéÈM?DÔùd1umk ÆEÊ
# - 10000 iterations :
# OÊët sans bes de  flèà se NBQ]WDèndex.]r mait pus «Wôe d, p psares je, viffque,
# Vèèsetui ôtrdet. me

# %% [markdown]
# ## Single Head Attention
#
# We will now implement the basic attention mechanism. For each pair of words in the sequence, this mechanism combines:
# - **Q** (*query*): the information being searched for,
# - **K** (*key*): the information retrieved,
# - **V** (*value*): a result vector calculated from the attention mechanism.
#
# ![single head attention](images/single_head_attention.png)
#
# ### Masking
#
# However, since we are using the model to generate sequences, we must not use characters that come after the current character—these are precisely the characters we aim to predict during training. *The future should not be used to predict the future.*
#
# To enforce this constraint, we integrate a **masking matrix** into the process. This matrix ensures that:
# - For the first character in the sequence, only that character is available for prediction (no context).
# - For the second character, only the first and second characters can be used.
# - For the third character, only the first three characters are accessible, and so on.
#
# This results in a **lower triangular matrix**, where each row is normalized (rows sum to 1).

# %%
T = 8

# first version of the contraints with matrix multiplication
# create a lower triangular matrix
weights0 = torch.tril(torch.ones(T,T))
# normalize each row
weights0 = weights0 / weights0.sum(1, keepdim=True) 
print (weights0)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# The [`softmax`](https://pytorch.org/docs/stable/generated/torch.nn.functional.softmax.html) function provides another way to achieve normalization.
#
# #### Question:
# - Verify that applying `softmax` results in the same lower triangular matrix.

# %%
tril = torch.tril(torch.ones(T,T))
weights = torch.tril(torch.ones(T,T))
weights = weights.masked_fill(tril== 0, float('-inf'))
weights = nn.functional.softmax(weights, dim=-1)
print (weights)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# ### Implementation
#
# We can now implement the attention layer based on the following formula:
#
# ![attention_formula](images/attention_formula.png)
#
# This involves computing the **queries (Q)**, **keys (K)**, and **values (V)**, applying the **masking mechanism**, and using the **softmax function** to normalize the attention scores before computing the weighted sum of values.

# %% [markdown]
# #### Questions:
#
# - Create the **key**, **query**, and **value** layers as linear layers of dimension `C × head_size`.
# - Apply these layers to `x`.
# - Compute the attention weights:
#   ```python
#   weights = query @ key.transpose(-2, -1)
#   ```
#   (Transpose the second and third dimensions of `key` to enable matrix multiplication).
# - Apply the **normalization factor** (typically, divide by `sqrt(head_size)`).
# - Apply the **triangular mask** and the **softmax** function to `weights`.
# - Apply the **value** layer to `x`.
# - Compute the final output:
#   ```python
#   out = weights @ value(x)
#   ```

# %%
head_size = 16
B, T, C = 4, 8, 32
x = torch.randn(B, T, C)
## YOUR CODE HERE
# define the Key layer  
key = nn.Linear(C, head_size)
# define the Query layer
query = nn.Linear(C, head_size)
# define the Value layer
value = nn.Linear(C, head_size)
# apply each layer to the input
k = key(x) # (B, T, head_size)
q = query(x) # (B, T, head_size)
v = value(x) # (B, T, head_size)
# compute the normalize product between Q and K 
weights = q @ k.transpose(-2, -1) # (B, T, head_size) @ (B, 16, head_size) -> (B, T, T)
# apply the mask (lower triangular matrix)
weights = weights.masked_fill(tril== 0, float('-inf'))
# apply the softmax
weights = nn.functional.softmax(weights, dim=-1)
###
out  = weights @ value(x) # (B, T, head_size)

# print the result
weights[0]
out[0]
# Out:
# tensor([[-0.6362, -0.4188, -0.0080, -0.9437, -0.6160, -0.8479,  1.0626, -0.0640,
#          -0.3146, -0.6117, -0.5345, -0.6560,  0.5265, -0.0256, -0.4360,  0.2714],
#         [-0.2589, -0.2909, -0.0310, -0.4907, -1.1566, -0.6855,  1.0608,  0.0780,
#          -0.0730, -0.0926, -1.0559, -0.3572,  0.3602,  0.2848, -0.8724,  0.4408],
#         [-0.2475, -0.5128, -0.0570, -0.6573, -0.6828, -0.7431,  1.0665, -0.0036,
#          -0.0652, -0.2540, -0.7453, -0.2234,  0.3860,  0.1675, -0.7187,  0.4907],
#         [-0.5520, -0.0995,  0.3032, -1.0879, -0.3326, -1.0994,  0.5990,  0.5321,
#           0.1107,  0.7054, -0.9655, -0.3828, -0.4680,  0.2289, -0.8370,  0.7312],
#         [-0.3882, -0.3452,  0.0862, -0.7315, -0.2911, -0.8869,  0.6409,  0.2841,
#           0.3711,  0.3101, -0.6071,  0.0550, -0.0964,  0.0861, -0.6670,  0.4687],
#         [-0.4577, -0.4752, -0.0689, -0.7345, -0.4218, -0.7973,  0.9233, -0.0162,
#           0.0316, -0.3979, -0.4016, -0.1854,  0.4166, -0.0313, -0.4157,  0.2613],
#         [-0.1209,  0.0351, -0.2393, -0.3423, -0.1618, -0.7818,  0.5375,  0.2424,
#           0.2243,  0.1892, -0.2268,  0.5028,  0.0833,  0.1519, -0.0943,  0.1605],
#         [-0.3626, -0.2430, -0.0477, -0.6396, -0.5208, -0.7753,  0.8686,  0.0201,
#          -0.1483, -0.2475, -0.5191, -0.2190,  0.3334,  0.1043, -0.4200,  0.3075]],
#        grad_fn=<SelectBackward0>)

# %% [markdown]
# ### Questions:
#
# - Copy your code into `gpt_single_head.py`:
#   - Define the **key**, **query**, and **value** layers in the **constructor** of the `Head` class.
#   - Implement the **computations** in the `forward` function.
# - Train the model.
# - What are the **training** and **validation** losses?
# - Does the generated text appear **better** compared to the previous model?

# %% [markdown]
# train loss 2.3423, val loss 2.4739

# %% [markdown]
# ## Multi-Head Attention
#
# Multi-head attention is simply the parallel computation of multiple **single-head attention** mechanisms. Each **single-head attention** output is concatenated to form the output of the **multi-head attention** module. In the original paper's illustration, the number of heads in the **multi-head attention** is denoted as `h`.
#
# To allow for **weighted combinations** of each single-head attention output, a **linear transformation layer** is added after concatenation.
#
# ![multi head attention](images/multi_head_attention.png)
#
# #### Questions:
#
# - In the **constructor**, create a list containing `num_heads` instances of the `Head` module using PyTorch’s [`ModuleList`](https://pytorch.org/docs/stable/generated/torch.nn.ModuleList.html).
# - In the `forward` function:
#   - Apply each **single-head attention** to the input.
#   - Concatenate the results using PyTorch’s [`cat`](https://pytorch.org/docs/stable/generated/torch.cat.html) function.

# %%
class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        ## YOUR CODE HERE
        ## list of num_heads modules of type Head
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        ###
        
    def forward(self, x):
        ## YOUR CODE HERE
        ## apply each head in self.heads to x and concat the results 
        out = torch.cat([h(x) for h in self.heads], dim=-1)

        return out

# %% [markdown]
# #### Questions:
#
# 1. **Copy** the file `gpt_single_head.py` and rename it as `gpt_multi_head.py`.
# 2. **Add** the `MultiHeadAttention` module in `gpt_multi_head.py`.
# 3. At the **beginning of the file**, add a parameter:
#    ```python
#    n_head = 4
#    ```
# 4. In the `BigramLanguageModel` module, **replace** the `Head` module with `MultiHeadAttention`, using the parameters:
#    ```python
#    num_heads = n_head
#    head_size = n_embd // n_head
#    ```
#    This ensures the total number of parameters remains **the same**.
# 5. **Retrain the model** and note:
#    - The total number of **parameters**
#    - The **training** and **validation** losses obtained
#
# **Expected Output Example:**
# ```
# 0.009893 M parameters
# step 4999: train loss 2.1570, val loss 2.1802
# ```

# %% [markdown]
# ## Adding a FeedForward Computation Layer
#
# After the **attention layers**, which collect information from the sequence, a **computation layer** is added to combine all the gathered information.
#
# This layer is a simple **Multi-Layer Perceptron (MLP)** with:
# - One **hidden layer**,
# - A **ReLU non-linearity** using [`ReLU`](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html).
#
# ### Architecture:
#
# <img src="images/multi_ff.png" alt="multi feedforward" width="200">

# %%
class FeedForward(nn.Module):
    """ a simple MLP with RELU """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, n_embd),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# #### Questions:
#
# 1. **Add** the `FeedForward` module to your `gpt_multi_head.py` file.
# 2. **Integrate** this `FeedForward` layer **after** the **multi-head attention** module.
# 3. **Retrain the model** and note:
#    - The total **number of parameters**
#    - The **training** and **validation** losses obtained
#
# **Expected Output Example:**
# ```
# 0.010949 M parameters
# step 4999: train loss 2.1290, val loss 2.1216
# ```

# %% [markdown]
# 0.011045 M parameters
#
# step 4999: train loss 2.1069, val loss 2.1455

# %% [markdown]
# ## Stacking Blocks
#
# The network we have built so far represents just **one block** of the final model. Now, we can **stack multiple blocks** of **multi-head attention** to create a **deeper** network.
#
# ### Architecture:
# ![multi feedforward](images/multi_bloc.png)
#
# The following code defines a **block**:

# %%
class Block(nn.Module):
    """ A single bloc of multi-head attention """

    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)

    def forward(self, x):
        x = self.sa(x)
        x = self.ffwd(x)
        return x

# %% [markdown]
# #### Questions:
#
# - Add the `Block` module to `gpt_multi_head.py`.
# - Modify the `BigramLanguageModel` code to include **three** instances of `Block(n_embd, n_head=4)`, using a [`Sequential`](https://pytorch.org/docs/stable/generated/torch.nn.Sequential.html) container **instead of** `MultiHeadAttention` and `FeedForward`.
# - Retrain the model and note:
#   - The **number of parameters**
#   - The **training** and **validation** losses obtained
#
# **Expected Output Example:**
# ```
# 0.019205 M parameters
# step 4999: train loss 2.2080, val loss 2.2213
# ```

# %% [markdown]
# 0.019493 M parameters
#
# step 4999: train loss 2.2031, val loss 2.2435

# %% [markdown]
# ## Improving Training
#
# If we want to continue increasing the **network size**, we need to incorporate layers that **enhance training stability** and **improve generalization** (reducing overfitting). These layers include:
#
# - **Skip connections** (or **residual connections**)
# - **Normalization layers**
# - **Dropout**
#
# ### Updated Architecture:
#
# <img src="images/multi_skip_norm.png" alt="multi feedforward" width="200">
#
# ---
#
# #### Questions:
#
# 1. In the `Block` module, **add a skip connection** by summing the input at each step:
#    ```python
#    x = x + self.sa(self.ln1(x))
#    x = x + self.ffwd(self.ln2(x))
#    ```
#
# 2. In the `Block` module, **add two** [`LayerNorm`](https://pytorch.org/docs/stable/generated/torch.nn.LayerNorm.html) layers of size `n_embd`:
#    - **Before** the `Multi-Head Attention` layer.
#    - **Before** the `FeedForward` layer.
#
# 3. **After the sequence of 3 blocks**, add a **LayerNorm** layer of size `n_embd`.
#
# 4. Define a variable at the **beginning of the file**:
#    ```python
#    dropout = 0.2
#    ```
#    Then add a [`Dropout`](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html) layer:
#    - **After** the `ReLU` activation in `FeedForward`.
#    - **After** the `Multi-Head Attention` layer in `MultiHeadAttention`.
#    - **After** the `softmax` layer in the single-head attention `Head`.
#
# 5. **Retrain the model** and note:
#    - The **number of parameters**
#    - The **training** and **validation** losses
#
# ---
#
# **Expected Output Example:**
# ```
# 0.019653 M parameters
# ```

# %% [markdown]
# 0.019941 M parameters
#
# step 4999: train loss 2.0611, val loss 2.0373

# %% [markdown]
# ## Conclusion
#
# The key components of **GPT-2** are now in place. The next step is to **scale up** the model and train it on a **much larger** dataset. For comparison, the parameters of [GPT-2](https://huggingface.co/transformers/v2.11.0/model_doc/gpt2.html) are:
#
# - **`vocab_size = 50257`** → GPT-2 models **subword tokens**, while we model **characters**. For us, `vocab_size = 100`.
# - **`n_positions = 1024`** → The maximum **context size**. For us, it's `block_size = 8`.
# - **`n_embd = 768`** → The **embedding dimension**. For us, it's `n_embd = 32`.
# - **`n_layer = 12`** → The number of **blocks**. For us, it's `3`.
# - **`n_head = 12`** → The number of **multi-head attention layers**. For us, it's `4`.
#
# Overall, **GPT-2** consists of **1.5 billion parameters** and was trained on **8 million web pages**, totaling **40 GB of text**.
#
# ---
#
# ### **Training Results**
# ```text
# 10.816613 M parameters
# step 0: train loss 4.7847, val loss 4.7701
# step 4999: train loss 0.2683, val loss 2.1161
# time: 31m47.910s
# ```
#
# ### **Generated Text Sample:**
#
# ```text
# Le pêcheur où l'homme en peu de Carevante
# Sa conter des chosses qu'en ses yoitn!
#
# Ils sont là-hauts parler à leurs ténèbres
# A ceux qu'on rêve aux oiseaux des cheveux,
# Et celus qu'on tourna jamais sous le front;
# Ils se disent tu mêle aux univers.
# J'ai vu Jean vu France, potte; petits contempler,
# Et petié calme au milibre et versait,
# M'éblouissant, emportant, écoute, ingorancessible,
# On meurt s'efferayait.....--Pas cont âme parle en Apparia!
# ```
